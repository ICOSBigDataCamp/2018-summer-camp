# %% [markdown]
# # Twitter data collection
#
# Note that you will need to have an API key from twitter to use this.

# %% [markdown]
# ## Imports
# - `pandas` is a package for handling and manipulating data.
# - `tweepy` is a package that helps you use the Twitter API in python.
# - `time` is a package that lets you work with time in python.

# %%
import pandas as pd
import tweepy
import time
import sys
import json

# %% [markdown]
# ## keys
# - you'll need API keys from twitter to use their API. Once you have them, they can go here.

# %%
keys = {'CONSUMER_KEY': 'xxx',
        'CONSUMER_SECRET': 'xxx'}

# %%
with open('twitter_auth', 'r') as f:
    keys = json.loads(f.read())    
keys
# Out:
# {'CONSUMER_KEY': '4ER7Uf3Bp8rjVHf2LKcQd1tFO',
#  'CONSUMER_SECRET': 'Jq83413Rg7nDhwmhJHlaLOUKvGo0hLrGbFlh8iJJqhGB6VICXS'}

# %%
auth = tweepy.AppAuthHandler(keys['CONSUMER_KEY'], 
                                  keys['CONSUMER_SECRET'])

api = tweepy.API(auth, wait_on_rate_limit=True, 
                 wait_on_rate_limit_notify=True)

if not api:
    print ("Can't Authenticate :(")
else:
    print('Authenticated successfully!')
# Out:
# Authenticated successfully!

# %% [markdown]
# ## User account names we want to get tweets for

# %%
users = ['nyctaxi', 'NYTWA', 'NYC_TMODA', 'YellowCabNYC', 
         'NYC_DOT', 'NYCTSubway']

# %% [markdown]
# ## Some functions to help us

# %%
def get_user_tweets(name, api):
    tweets = []
    try: 
        for status in tweepy.Cursor(api.user_timeline, 
                                    screen_name=name, 
                                    count=200).items():
            try:
                tweets.append(status._json)
            except:
                pass
    except:
        pass
    return tweets

def get_user_followers(name, api):
    followers = []
    try: 
        for status in tweepy.Cursor(api.followers, 
                                    screen_name=name, 
                                    count=200).items():
            try:
                followers.append(status._json)
            except:
                pass
            if len(followers) >= 5000:
                print(name, "has more than 5,000 followers. Stopping at 5,000.")
                break
    except:
        pass
    return followers

def get_user_followers_ids(name, api):
    followers = []
    try: 
        for status in tweepy.Cursor(api.followers_ids, 
                                    screen_name=name, 
                                    count=5000).items():
            try:
                followers.append(status)
            except:
                pass
            if len(followers) >= 5000:
                print(name, "has more than 5,000 followers. Stopping at 5,000.")
                break
            
    except:
        pass
    return followers


def get_user_friends(name, api):
    friends = []
    try: 
        for status in tweepy.Cursor(api.friends, 
                                    screen_name=name, 
                                    count=200).items():
            try:
                friends.append(status._json)
            except:
                pass
            if len(friends) >= 5000:
                print(name, "has more than 5,000 friends. Stopping at 5,000.")
                break
    except:
        pass
    return friends

def get_user_friends_ids(name, api):
    friends = []
    try: 
        for status in tweepy.Cursor(api.friends_ids, 
                                    screen_name=name, 
                                    count=5000).items():
            try:
                friends.append(status)
            except:
                pass
            if len(friends) >= 5000:
                print(name, "has more than 5,000 friends. Stopping at 5,000.")
                break
    except:
        pass
    return friends

# %%
all_tweets = []

for u in users:
    print("Getting tweets for user", u)
    tweets = get_user_tweets(u, api)
    print("Found", len(tweets), 'tweets.')
    all_tweets.extend(tweets)
    
print('Done!')
# Out:
# Getting tweets for user nyctaxi
# Found 3195 tweets.
# Getting tweets for user NYTWA
# Found 3181 tweets.
# Getting tweets for user NYC_TMODA
# Found 30 tweets.
# Getting tweets for user YellowCabNYC
# Found 349 tweets.
# Getting tweets for user NYC_DOT
# Found 3216 tweets.
# Getting tweets for user NYCTSubway
# Found 3218 tweets.
# Done!

# %% [markdown]
# ## What's the data look like?

# %%
all_tweets[0]
# Out:
# {'created_at': 'Fri Apr 13 16:57:57 +0000 2018',
#  'id': 984838110532993024,
#  'id_str': '984838110532993024',
#  'text': 'RT @NYLawSchool: Meera Joshi refers to @nyctaxi ’s work with Families for Safe Streets, Transportation Alternatives, and the New York City…',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'NYLawSchool',
#     'name': 'New York Law School',
#     'id': 42979354,
#     'id_str': '42979354',
#     'indices': [3, 15]},
#    {'screen_name': 'nyctaxi',
#     'name': 'NYC TLC',
#     'id': 94163495,
#     'id_str': '94163495',
#     'indices': [39, 47]}],
#   'urls': []},
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 94163495,
#   'id_str': '94163495',
#   'name': 'NYC TLC',
#   'screen_name': 'nyctaxi',
#   'location': 'New York, NY',
#   'description': 'The TLC is the City agency that regulates app-based and traditional black & livery cars, yellow & green taxicabs,  ambulettes, commuter vans & some limousines.',
#   'url': 'https://t.co/vb35n2OpJo',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/vb35n2OpJo',
#       'expanded_url': 'http://nyc.gov/tlc',
#       'display_url': 'nyc.gov/tlc',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 13493,
#   'friends_count': 660,
#   'listed_count': 366,
#   'created_at': 'Wed Dec 02 20:00:22 +0000 2009',
#   'favourites_count': 1142,
#   'utc_offset': -14400,
#   'time_zone': 'Eastern Time (US & Canada)',
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 4222,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'A8C75A',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/646340365897854976/1ta6i3EL_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/646340365897854976/1ta6i3EL_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/94163495/1412198408',
#   'profile_link_color': 'F28043',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Fri Apr 13 13:17:22 +0000 2018',
#   'id': 984782600400195590,
#   'id_str': '984782600400195590',
#   'text': 'Meera Joshi refers to @nyctaxi ’s work with Families for Safe Streets, Transportation Alternatives, and the New Yor… https://t.co/5ujinCfjb6',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'nyctaxi',
#      'name': 'NYC TLC',
#      'id': 94163495,
#      'id_str': '94163495',
#      'indices': [22, 30]}],
#    'urls': [{'url': 'https://t.co/5ujinCfjb6',
#      'expanded_url': 'https://twitter.com/i/web/status/984782600400195590',
#      'display_url': 'twitter.com/i/web/status/9…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 42979354,
#    'id_str': '42979354',
#    'name': 'New York Law School',
#    'screen_name': 'NYLawSchool',
#    'location': 'TriBeCa, New York',
#    'description': 'Founded in 1891, New York Law School is an independent law school located in lower Manhattan near the city’s centers of law, government, and finance.',
#    'url': 'http://t.co/TjBS0QQ6hi',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/TjBS0QQ6hi',
#        'expanded_url': 'http://www.nyls.edu',
#        'display_url': 'nyls.edu',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 5859,
#    'friends_count': 1096,
#    'listed_count': 161,
#    'created_at': 'Wed May 27 22:10:59 +0000 2009',
#    'favourites_count': 822,
#    'utc_offset': -14400,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 5172,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '639EC8',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/690879191/f31f14095368064ff372b5643ed58843.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/690879191/f31f14095368064ff372b5643ed58843.jpeg',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/519201070136844288/MPUHaQji_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/519201070136844288/MPUHaQji_normal.jpeg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/42979354/1412622146',
#    'profile_link_color': '3B94D9',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'B6B7BA',
#    'profile_text_color': '3C3940',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 3,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'is_quote_status': False,
#  'retweet_count': 2,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %% [markdown]
# ## Save our data

# %%
with open('tweets_raw.json', 'w') as out_file:
    for t in all_tweets:
        json.dump(t, out_file)
        out_file.write('\n')

# %% [markdown]
# ## Convert it to pandas

# %%
df = pd.DataFrame(all_tweets)
df.head()
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Fri Apr 13 16:57:57 +0000 2018
# 1         None        None  Thu Apr 12 14:39:25 +0000 2018
# 2         None        None  Thu Apr 12 14:36:39 +0000 2018
# 3         None        None  Mon Apr 09 17:43:50 +0000 2018
# 4         None        None  Mon Apr 09 15:36:19 +0000 2018
#
#                                             entities extended_entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
#
#    favorite_count  favorited   geo                  id              id_str  \
# 0               0      False  None  984838110532993024  984838110532993024
# 1               1      False  None  984440857825763328  984440857825763328
# 2               0      False  None  984440162619936771  984440162619936771
# 3               0      False  None  983400107155566592  983400107155566592
# 4               0      False  None  983368016061784064  983368016061784064
#
#                          ...                         quoted_status  \
# 0                        ...                                   NaN
# 1                        ...                                   NaN
# 2                        ...                                   NaN
# 3                        ...                                   NaN
# 4                        ...                                   NaN
#
#    quoted_status_id quoted_status_id_str  retweet_count retweeted  \
# 0               NaN                  NaN              2     False
# 1               NaN                  NaN              0     False
# 2               NaN                  NaN              1     False
# 3               NaN                  NaN              8     False
# 4               NaN                  NaN              0     False
#
#                                     retweeted_status  \
# 0  {'created_at': 'Fri Apr 13 13:17:22 +0000 2018...
# 1                                                NaN
# 2  {'created_at': 'Thu Apr 12 13:53:27 +0000 2018...
# 3  {'created_at': 'Mon Apr 09 16:31:06 +0000 2018...
# 4                                                NaN
#
#                                               source  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com" rel="nofollow">Tw...
# 4  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                                 text truncated  \
# 0  RT @NYLawSchool: Meera Joshi refers to @nyctax...     False
# 1  @sarah_stern @Uber Hi Ms. Stern, do you have t...     False
# 2  RT @NYLawSchool: Tomorrow—Join us for coffee, ...     False
# 3  RT @NYCVotes: Our democracy is powered by acti...     False
# 4  @djcoreycraig @Uber @lyft @juno Thank you very...     False
#
#                                                 user
# 0  {'id': 94163495, 'id_str': '94163495', 'name':...
# 1  {'id': 94163495, 'id_str': '94163495', 'name':...
# 2  {'id': 94163495, 'id_str': '94163495', 'name':...
# 3  {'id': 94163495, 'id_str': '94163495', 'name':...
# 4  {'id': 94163495, 'id_str': '94163495', 'name':...
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Friends

# %%
all_friends = []

for u in users:
    print("Getting friends for user", u)
    friends = get_user_friends(u, api)
    print("Found", len(friends), 'friends.')
    all_friends.extend(friends)
    
print('Done!')
# Out:
# Getting friends for user nyctaxi
# Found 660 followers.
# Getting friends for user NYTWA
# Found 405 followers.
# Getting friends for user NYC_TMODA
# Found 70 followers.
# Getting friends for user YellowCabNYC
# Found 1782 followers.
# Getting friends for user NYC_DOT
# Found 874 followers.
# Getting friends for user NYCTSubway
# Found 294 followers.
# Done!

# %%
all_friends[0]
# Out:
# {'id': 333231586,
#  'id_str': '333231586',
#  'name': 'Steve D Luddite',
#  'screen_name': 'mrloopy52',
#  'location': 'London SE12',
#  'description': "Ex London Fireman, Taxi Driver since 1991. Sack Chapman. Crush touts' cars and rickshaws. GB. Proud Luddite #52%",
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 1267,
#  'friends_count': 420,
#  'listed_count': 62,
#  'created_at': 'Mon Jul 11 06:10:49 +0000 2011',
#  'favourites_count': 922,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': False,
#  'statuses_count': 45218,
#  'lang': 'en',
#  'status': {'created_at': 'Sun Apr 15 18:25:19 +0000 2018',
#   'id': 985584874114469893,
#   'id_str': '985584874114469893',
#   'text': 'RT @steve_garelick: So I have been advised by a reliable source that Uber are about to message users about the Local elections. I am concer…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'steve_garelick',
#      'name': 'Steve Garelick',
#      'id': 3125229772,
#      'id_str': '3125229772',
#      'indices': [3, 18]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Apr 13 10:18:02 +0000 2018',
#    'id': 984737469479444481,
#    'id_str': '984737469479444481',
#    'text': 'So I have been advised by a reliable source that Uber are about to message users about the Local elections. I am co… https://t.co/PFhspenuT8',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/PFhspenuT8',
#       'expanded_url': 'https://twitter.com/i/web/status/984737469479444481',
#       'display_url': 'twitter.com/i/web/status/9…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 117,
#    'favorite_count': 72,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 117,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/792309528641413120/yb15_OYx_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/792309528641413120/yb15_OYx_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/333231586/1407136171',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': None,
#  'follow_request_sent': None,
#  'notifications': None,
#  'muting': None,
#  'blocking': None,
#  'blocked_by': None,
#  'translator_type': 'none'}

# %%
with open('data/friends_raw.json', 'w') as out_file:
    for t in all_friends:
        json.dump(t, out_file)
        out_file.write('\n')

# %% [markdown]
# ## Followers

# %%
all_followers = []

for u in users:
    print("Getting followers for user", u)
    followers = get_user_followers(u, api)
    print("Found", len(followers), 'followers.')
    all_followers.extend(followers)
    
print('Done!')
# Out:
# Getting followers for user nyctaxi
# nyctaxi has more than 5,000 followers. Stopping at 5,000.
# Found 5000 followers.
# Getting followers for user NYTWA
# Rate limit reached. Sleeping for: 847

# %%
all_followers[0]

# %%
with open('data/followers_raw.json', 'w') as out_file:
    for t in all_followers:
        json.dump(t, out_file)
        out_file.write('\n')

# %% [markdown]
# ## Followers IDs only

# %%
all_followers_ids = []

for u in users:
    print("Getting follower IDs for user", u)
    followers = get_user_followers_ids(u, api)
    print("Found", len(followers), 'followers.')
    all_followers_ids.extend(followers)
    
print('Done!')

# %%
all_followers[0]

# %%
with open('data/followers_ids_raw.json', 'w') as out_file:
    for t in all_followers_ids:
        json.dump(t, out_file)
        out_file.write('\n')
